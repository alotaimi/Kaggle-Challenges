# %% [markdown]
# This dataset from https://www.kaggle.com/datasets/adammaus/predicting-churn-for-bank-customers

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pycaret
from pycaret.classification import *

# %%
dataset = pd.read_csv('Bank Customer Churn Prediction.csv')

# %%
len(dataset['customer_id'].unique())
# Out:
# 10000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
dataset.dtypes
# Out:
# customer_id           int64
# credit_score          int64
# country              object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# products_number       int64
# credit_card           int64
# active_member         int64
# estimated_salary    float64
# churn                 int64
# dtype: object

# %%
dataset['country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
dataset = pd.get_dummies(dataset,columns=['country','gender'])

# %%
print(' %d 1 %d 0 ' %(len(dataset[dataset['churn'] == 1]) , len(dataset[dataset['churn'] == 0])))
# Out:
#  2037 1 7963 0

# %%
correlation = dataset.corr()
correlation_churn = abs(correlation['churn'])
correlation_churn.sort_values(ascending=False)
# Out:
# churn               1.000000
# age                 0.285323
# country_Germany     0.173488
# active_member       0.156128
# balance             0.118533
# gender_Female       0.106512
# gender_Male         0.106512
# country_France      0.104955
# country_Spain       0.052667
# products_number     0.047820
# credit_score        0.027094
# tenure              0.014001
# estimated_salary    0.012097
# credit_card         0.007138
# customer_id         0.006248
# Name: churn, dtype: float64

# %%
drop_list_corr = sorted(list(correlation_churn[correlation_churn < 0.01].index))
print(drop_list_corr)
# Out:
# ['credit_card', 'customer_id']

# %%
dataset.drop(labels=drop_list_corr, axis=1, inplace=True)

# %%
dataset.columns
# Out:
# Index(['credit_score', 'age', 'tenure', 'balance', 'products_number',
#        'active_member', 'estimated_salary', 'churn', 'country_France',
#        'country_Germany', 'country_Spain', 'gender_Female', 'gender_Male'],
#       dtype='object')

# %%
dataset[['balance']].describe()
# Out:
#              balance
# count   10000.000000
# mean    76485.889288
# std     62397.405202
# min         0.000000
# 25%         0.000000
# 50%     97198.540000
# 75%    127644.240000
# max    250898.090000

# %%
dataset['log_balance'] = dataset['balance'].apply(lambda x: np.log10(x+1))
dataset.drop('balance', axis=1, inplace=True)

# %%
churn_df = dataset.loc[dataset['churn'] == 1]
nonchurn_df = dataset.loc[dataset['churn'] == 0][:2037]

normal_distributed_df = pd.concat([churn_df, nonchurn_df])

df_new = normal_distributed_df.sample(frac=1, random_state=42)

# %%
df_new = dataset.copy()

# %%
s = setup(data=dataset,target='churn',train_size = .8,preprocess=False, 
          remove_multicollinearity = True, multicollinearity_threshold = 0.9,
          fix_imbalance = False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8c49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8c49_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c8c49_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8c49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8c49_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_c8c49_row0_col1" class="data row0 col1" >2495</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8c49_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c8c49_row1_col1" class="data row1 col1" >churn</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8c49_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_c8c49_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8c49_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_c8c49_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8c49_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_c8c49_row4_col1" class="data row4 col1" >(10000, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8c49_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_c8c49_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8c49_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_c8c49_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8c49_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_c8c49_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8c49_row8_col0" class="data row8 col0" >Transformed Train Set</td>
#       <td id="T_c8c49_row8_col1" class="data row8 col1" >(8000, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8c49_row9_col0" class="data row9 col0" >Transformed Test Set</td>
#       <td id="T_c8c49_row9_col1" class="data row9 col1" >(2000, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c8c49_row10_col0" class="data row10 col0" >Shuffle Train-Test</td>
#       <td id="T_c8c49_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c8c49_row11_col0" class="data row11 col0" >Stratify Train-Test</td>
#       <td id="T_c8c49_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c8c49_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_c8c49_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c8c49_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_c8c49_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c8c49_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_c8c49_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c8c49_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_c8c49_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c8c49_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_c8c49_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c8c49_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_c8c49_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c8c49_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_c8c49_row18_col1" class="data row18 col1" >0758</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c8c49_row19_col0" class="data row19 col0" >Fix Imbalance</td>
#       <td id="T_c8c49_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8c49_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c8c49_row20_col0" class="data row20 col0" >Fix Imbalance Method</td>
#       <td id="T_c8c49_row20_col1" class="data row20 col1" >SMOTE</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_4ce58 th {
#   text-align: left;
# }
# #T_4ce58_row0_col0, #T_4ce58_row0_col3, #T_4ce58_row1_col0, #T_4ce58_row1_col1, #T_4ce58_row1_col2, #T_4ce58_row1_col3, #T_4ce58_row1_col4, #T_4ce58_row1_col5, #T_4ce58_row1_col6, #T_4ce58_row1_col7, #T_4ce58_row2_col0, #T_4ce58_row2_col1, #T_4ce58_row2_col2, #T_4ce58_row2_col3, #T_4ce58_row2_col4, #T_4ce58_row2_col5, #T_4ce58_row2_col6, #T_4ce58_row2_col7, #T_4ce58_row3_col0, #T_4ce58_row3_col1, #T_4ce58_row3_col2, #T_4ce58_row3_col3, #T_4ce58_row3_col4, #T_4ce58_row3_col5, #T_4ce58_row3_col6, #T_4ce58_row3_col7, #T_4ce58_row4_col0, #T_4ce58_row4_col1, #T_4ce58_row4_col2, #T_4ce58_row4_col3, #T_4ce58_row4_col4, #T_4ce58_row4_col5, #T_4ce58_row4_col6, #T_4ce58_row4_col7, #T_4ce58_row5_col0, #T_4ce58_row5_col1, #T_4ce58_row5_col2, #T_4ce58_row5_col3, #T_4ce58_row5_col4, #T_4ce58_row5_col5, #T_4ce58_row5_col6, #T_4ce58_row5_col7, #T_4ce58_row6_col0, #T_4ce58_row6_col1, #T_4ce58_row6_col2, #T_4ce58_row6_col3, #T_4ce58_row6_col4, #T_4ce58_row6_col5, #T_4ce58_row6_col6, #T_4ce58_row6_col7, #T_4ce58_row7_col0, #T_4ce58_row7_col1, #T_4ce58_row7_col2, #T_4ce58_row7_col3, #T_4ce58_row7_col4, #T_4ce58_row7_col5, #T_4ce58_row7_col6, #T_4ce58_row7_col7, #T_4ce58_row8_col0, #T_4ce58_row8_col1, #T_4ce58_row8_col2, #T_4ce58_row8_col4, #T_4ce58_row8_col5, #T_4ce58_row8_col6, #T_4ce58_row8_col7, #T_4ce58_row9_col0, #T_4ce58_row9_col1, #T_4ce58_row9_col2, #T_4ce58_row9_col3, #T_4ce58_row9_col4, #T_4ce58_row9_col5, #T_4ce58_row9_col6, #T_4ce58_row9_col7, #T_4ce58_row10_col0, #T_4ce58_row10_col1, #T_4ce58_row10_col2, #T_4ce58_row10_col3, #T_4ce58_row10_col4, #T_4ce58_row10_col5, #T_4ce58_row10_col6, #T_4ce58_row10_col7, #T_4ce58_row11_col0, #T_4ce58_row11_col1, #T_4ce58_row11_col2, #T_4ce58_row11_col3, #T_4ce58_row11_col4, #T_4ce58_row11_col5, #T_4ce58_row11_col6, #T_4ce58_row11_col7, #T_4ce58_row12_col0, #T_4ce58_row12_col1, #T_4ce58_row12_col2, #T_4ce58_row12_col3, #T_4ce58_row12_col4, #T_4ce58_row12_col5, #T_4ce58_row12_col6, #T_4ce58_row12_col7 {
#   text-align: left;
# }
# #T_4ce58_row0_col1, #T_4ce58_row0_col2, #T_4ce58_row0_col4, #T_4ce58_row0_col5, #T_4ce58_row0_col6, #T_4ce58_row0_col7, #T_4ce58_row8_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4ce58_row0_col8, #T_4ce58_row1_col8, #T_4ce58_row2_col8, #T_4ce58_row3_col8, #T_4ce58_row4_col8, #T_4ce58_row5_col8, #T_4ce58_row6_col8, #T_4ce58_row8_col8, #T_4ce58_row9_col8, #T_4ce58_row10_col8, #T_4ce58_row11_col8, #T_4ce58_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4ce58_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4ce58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ce58_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4ce58_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4ce58_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4ce58_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4ce58_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4ce58_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4ce58_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4ce58_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4ce58_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce58_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_4ce58_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_4ce58_row0_col1" class="data row0 col1" >0.8611</td>
#       <td id="T_4ce58_row0_col2" class="data row0 col2" >0.8657</td>
#       <td id="T_4ce58_row0_col3" class="data row0 col3" >0.4681</td>
#       <td id="T_4ce58_row0_col4" class="data row0 col4" >0.7672</td>
#       <td id="T_4ce58_row0_col5" class="data row0 col5" >0.5806</td>
#       <td id="T_4ce58_row0_col6" class="data row0 col6" >0.5033</td>
#       <td id="T_4ce58_row0_col7" class="data row0 col7" >0.5258</td>
#       <td id="T_4ce58_row0_col8" class="data row0 col8" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_4ce58_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_4ce58_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_4ce58_row1_col1" class="data row1 col1" >0.8589</td>
#       <td id="T_4ce58_row1_col2" class="data row1 col2" >0.8463</td>
#       <td id="T_4ce58_row1_col3" class="data row1 col3" >0.4675</td>
#       <td id="T_4ce58_row1_col4" class="data row1 col4" >0.7533</td>
#       <td id="T_4ce58_row1_col5" class="data row1 col5" >0.5765</td>
#       <td id="T_4ce58_row1_col6" class="data row1 col6" >0.4975</td>
#       <td id="T_4ce58_row1_col7" class="data row1 col7" >0.5181</td>
#       <td id="T_4ce58_row1_col8" class="data row1 col8" >0.1930</td>
#     </tr>
#     <tr>
#       <th id="T_4ce58_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_4ce58_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_4ce58_row2_col1" class="data row2 col1" >0.8512</td>
#       <td id="T_4ce58_row2_col2" class="data row2 col2" >0.8404</td>
#       <td id="T_4ce58_row2_col3" class="data row2 col3" >0.4438</td>
#       <td id="T_4ce58_row2_col4" class="data row2 col4" >0.7272</td>
#       <td id="T_4ce58_row2_col5" class="data row2 col5" >0.5508</td>
#       <td id="T_4ce58_row2_col6" class="data row2 col6" >0.4680</td>
#       <td id="T_4ce58_row2_col7" class="data row2 col7" >0.4887</td>
#       <td id="T_4ce58_row2_col8" class="data row2 col8" >0.1470</td>
#     </tr>
#     <tr>
#       <th id="T_4ce58_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_4ce58_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_4ce58_row3_col1" class="data row3 col1" >0.8508</td>
#       <td id="T_4ce58_row3_col2" class="data row3 col2" >0.8446</td>
#       <td id="T_4ce58_row3_col3" class="data row3 col3" >0.4645</td>
#       <td id="T_4ce58_row3_col4" class="data row3 col4" >0.7118</td>
#       <td id="T_4ce58_row3_col5" class="data row3 col5" >0.5612</td>
#       <td id="T_4ce58_row3_col6" class="data row3 col6" >0.4761</td>
#       <td id="T_4ce58_row3_col7" class="data row3 col7" >0.4924</td>
#       <td id="T_4ce58_row3_col8" class="data row3 col8" >0.1190</td>
#     </tr>
#     <tr>
#       <th id="T_4ce58_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_4ce58_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_4ce58_row4_col1" class="data row4 col1" >0.8074</td>
#       <td id="T_4ce58_row4_col2" class="data row4 col2" >0.7678</td>
#       <td id="T_4ce58_row4_col3" class="data row4 col3" >0.2356</td>
#       <td id="T_4ce58_row4_col4" class="data row4 col4" >0.5820</td>
#       <td id="T_4ce58_row4_col5" class="data row4 col5" >0.3345</td>
#       <td id="T_4ce58_row4_col6" class="data row4 col6" >0.2449</td>
#       <td id="T_4ce58_row4_col7" class="data row4 col7" >0.2797</td>
#       <td id="T_4ce58_row4_col8" class="data row4 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_4ce58_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_4ce58_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_4ce58_row5_col1" class="data row5 col1" >0.8051</td>
#       <td id="T_4ce58_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_4ce58_row5_col3" class="data row5 col3" >0.1312</td>
#       <td id="T_4ce58_row5_col4" class="data row5 col4" >0.6354</td>
#       <td id="T_4ce58_row5_col5" class="data row5 col5" >0.2160</td>
#       <td id="T_4ce58_row5_col6" class="data row5 col6" >0.1566</td>
#       <td id="T_4ce58_row5_col7" class="data row5 col7" >0.2220</td>
#       <td id="T_4ce58_row5_col8" class="data row5 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_4ce58_level0_row6" class="row_heading level0 row6" >svm</th>
#       <td id="T_4ce58_row6_col0" class

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2969">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2969_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a2969_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a2969_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a2969_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a2969_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a2969_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a2969_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a2969_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2969_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2969_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a2969_row0_col1" class="data row0 col1" >0.8755</td>
#       <td id="T_a2969_row0_col2" class="data row0 col2" >0.8658</td>
#       <td id="T_a2969_row0_col3" class="data row0 col3" >0.4923</td>
#       <td id="T_a2969_row0_col4" class="data row0 col4" >0.7901</td>
#       <td id="T_a2969_row0_col5" class="data row0 col5" >0.6066</td>
#       <td id="T_a2969_row0_col6" class="data row0 col6" >0.5374</td>
#       <td id="T_a2969_row0_col7" class="data row0 col7" >0.5586</td>
#     </tr>
#   </tbody>
# </table>
#       credit_score   age tenure products_number active_member  \
# 0            724.0  30.0     10               2             1
# 1            479.0  35.0      4               1             1
# 2            667.0  38.0      6               1             1
# 3            523.0  36.0      8               1             0
# 4            651.0  39.0      8               1             0
# ...            ...   ...    ...             ...           ...
# 1995         683.0  47.0      1               2             0
# 1996         739.0  36.0      0               2             0
# 1997         709.0  41.0      3               2             0
# 1998         595.0  34.0      2               2             1
# 1999         680.0  31.0      3               3             1
#
#       estimated_salary  country_France  country_Germany  country_Spain  \
# 0         54265.550781               1                0              0
# 1         47251.789062               0                1              0
# 2         73963.171875               1                0              0
# 3         13197.440430               0                0              1
# 4        137452.562500               1                0              0
# ...                ...             ...              ...            ...
# 1995     148989.156250               1                0              0
# 1996     133465.562500               1                0              0
# 1997      71672.859375               1                0              0
# 1998     156309.515625               0                1              0
# 1999     176433.593750               0                1              0
#
#       gender_Female  gender_Male  log_balance  churn  Label   Score
# 0                 0            1     0.000000      0      0  0.9840
# 1                 0            1     5.142139      1      0  0.8424
# 2                 1            0     5.159667      1      0  0.8987
# 3                 1            0     5.055690      0      0  0.7776
# 4                 1            0     0.000000      0      0  0.6446
# ...             ...          ...          ...    ...    ...     ...
# 1995              0            1     0.000000      0      0  0.8496
# 1996              1            0     0.000000      0      0  0.9496
# 1997              1            0     5.176964      0      0  0.9056
# 1998              0            1     4.944327      0      0  0.9545
# 1999              1            0     5.104939      0      1  0.8979
#
# [2000 rows x 15 columns]
